# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline 
fig, ax = plt.subplots() 

x = [215, 237, 237, 215, 193, 193, 193, 215, 239, 261, 261, 261, 261, 239, 216, 194, 172]
y = [280, 280, 258, 258, 258, 280, 304, 304, 304, 306, 284, 263, 239, 238, 237, 237, 239]

plt.scatter(x = x, y = y)
plt.title("Crystal positions", fontsize = 20)
plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
plt.text(218, 275, "C3", fontsize = 23)
plt.text(264, 232, "A5", fontsize = 23)
plt.ylim(350, 220)
plt.xlabel("Table X position (mm)", fontsize = 15)
plt.ylabel("Table Y position (mm)", fontsize = 15)
plt.grid()
plt.show()

# %% [markdown]
# ### 9/25
